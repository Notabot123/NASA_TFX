# %%
import numpy as np # numbers and algebra in python
import pandas as pd # tables and processing tabular data

# %%
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import GridSearchCV
from scikeras.wrappers import KerasRegressor

# %%
index_names = ['unit_number', 'time_cycles']
setting_names = ['setting_1', 'setting_2', 'setting_3']
sensor_names = ['s_{}'.format(i+1) for i in range(0,21)]
col_names = index_names + setting_names + sensor_names

# %%
dirPath = './archive/CMaps/'

train = pd.read_csv(dirPath + 'train_FD001.txt',sep='\s+',names=col_names)
test = pd.read_csv(dirPath + 'test_FD001.txt',sep='\s+',names=col_names)
y_test = pd.read_csv(dirPath + 'RUL_FD001.txt',sep='\s+',header=None)

# %%
train[index_names].groupby('unit_number').max().describe()
# Out:
#        time_cycles
# count   100.000000
# mean    206.310000
# std      46.342749
# min     128.000000
# 25%     177.000000
# 50%     199.000000
# 75%     229.250000
# max     362.000000

# %%
def gate_the_RUL(train,cap=150):
    # Rectifier
    train['RUL'] = np.minimum(train['RUL'],cap)
    return train

def add_remaining_useful_life(df):
    # Get the total number of cycles for each unit
    grouped_by_unit = df.groupby(by="unit_number")
    max_cycle = grouped_by_unit["time_cycles"].max()
    
    # Merge the max cycle back into the original frame
    result_frame = df.merge(max_cycle.to_frame(name='max_cycle'), left_on='unit_number', right_index=True)
    
    # Calculate remaining useful life for each row
    remaining_useful_life = result_frame["max_cycle"] - result_frame["time_cycles"]
    result_frame["RUL"] = remaining_useful_life
    
    # drop max_cycle as it's no longer needed
    result_frame = result_frame.drop("max_cycle", axis=1)
    return result_frame

# %%
# Here are a small selection of useful looking signals, along with our taregt (RUL)
good_sensors = ['s_2', 's_3', 's_4', 's_7', 's_8']
pd.plotting.scatter_matrix(train.loc[:,good_sensors], alpha=0.2)
plt.show()

# %% [markdown]
# As we discussed last week, we can gate the RUL during training if we "don't care about it above a threshold".
# Consider histograms later in this script to understand why

# %%
train = add_remaining_useful_life(train)
train = gate_the_RUL(train,cap=150)

train[index_names+['RUL']] # last thing in cell prints out
# Out:
#        unit_number  time_cycles  RUL
# 0                1            1  150
# 1                1            2  150
# 2                1            3  150
# 3                1            4  150
# 4                1            5  150
# ...            ...          ...  ...
# 20626          100          196    4
# 20627          100          197    3
# 20628          100          198    2
# 20629          100          199    1
# 20630          100          200    0
#
# [20631 rows x 3 columns]

# %%
# these seem not worth keeping
import warnings
warnings.filterwarnings("ignore")
# drop_sensors = ['s_1','s_5','s_16','s_18','s_19'] # as per last week..
drop_sensors = ['s_1','s_5','s_6','s_10','s_16','s_18','s_19'] # new bad signals noted. 

pd.plotting.scatter_matrix(train.loc[:,drop_sensors])
plt.show()

# %%
# this time let's keep the cycles (normalised) showing current engine life
drop_labels = ['unit_number']+setting_names+drop_sensors # ['unit_number'] was index_names

# %%
X_train = train.drop(drop_labels, axis=1)
y_train = X_train.pop('RUL')

# %%
X_test = test.groupby('unit_number').last().reset_index().drop(drop_labels, axis=1)

# %%
X_test
# Out:
#     time_cycles     s_2      s_3      s_4     s_7      s_8      s_9   s_11  \
# 0            31  642.58  1581.22  1398.91  554.42  2388.08  9056.40  47.23
# 1            49  642.55  1586.59  1410.83  553.52  2388.10  9044.77  47.67
# 2           126  642.88  1589.75  1418.89  552.59  2388.16  9049.26  47.88
# 3           106  642.78  1594.53  1406.88  552.64  2388.13  9051.30  47.65
# 4            98  642.27  1589.94  1419.36  553.29  2388.10  9053.99  47.46
# ..          ...     ...      ...      ...     ...      ...      ...    ...
# 95           97  642.30  1590.88  1397.94  553.99  2388.03  9062.41  47.14
# 96          134  642.59  1582.96  1410.92  554.05  2388.06  9076.36  47.38
# 97          121  642.68  1599.51  1415.47  553.44  2388.13  9062.34  47.66
# 98           97  642.00  1585.03  1397.98  554.75  2388.01  9067.16  47.26
# 99          198  642.95  1601.62  1424.99  552.48  2388.06  9155.03  47.80
#
#       s_12     s_13     s_14    s_15  s_17   s_20     s_21
# 0   521.79  2388.06  8130.11  8.4024   393  38.81  23.3552
# 1   521.74  2388.09  8126.90  8.4505   391  38.81  23.2618
# 2   520.83  2388.14  8131.46  8.4119   395  38.93  23.2740
# 3   521.88  2388.11  8133.64  8.4634   395  38.58  23.2581
# 4   521.00  2388.15  8125.74  8.4362   394  38.75  23.4117
# ..     ...      ...      ...     ...   ...    ...      ...
# 95  522.30  2388.01  8148.24  8.4110   391  38.96  23.4606
# 96  521.58  2388.06  8155.48  8.4500   395  38.61  23.2953
# 97  521.53  2388.09  8146.39  8.4235   394  38.76  23.3608
# 98  521.82  2388.02  8150.38  8.4003   391  38.95  23.3595
# 99  521.07  2388.05  8214.64  8.4903   396  38.70  23.1855
#
# [100 rows x 15 columns]

# %%
# zero-centered normalise (standardise or zscore)

X_train = (X_train - np.mean(X_train)) / np.std(X_train)
X_test = (X_test - np.mean(X_test)) / np.std(X_test)

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Dense(units=256))
model.add(tf.keras.layers.BatchNormalization()) # bnorm
model.add(tf.keras.layers.Activation("relu"))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=128))
model.add(tf.keras.layers.BatchNormalization()) # bnorm
model.add(tf.keras.layers.Activation("relu"))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=128))
model.add(tf.keras.layers.BatchNormalization()) # bnorm
model.add(tf.keras.layers.Activation("relu"))
model.add(tf.keras.layers.Dropout(0.2))
model.add(tf.keras.layers.Dense(units=1))

# %% [markdown]
# In the next section we define a custom metric, we manually split and shuffle data

# %%
import keras.backend as K # this will let us easily view rmse during training
def root_mean_squared_error(y_true, y_pred):
    # root_mean_squared_error as metric in compile
        return K.sqrt(K.mean(K.square(y_pred - y_true), axis=-1)) 

n = len(X_train)
r = np.random.permutation(n)
# shuffle
X_train = X_train.iloc[r,:]
y_train = y_train.iloc[r]

splt = int(np.floor(n * 0.8))
X_val = X_train.iloc[splt:,:]
X_train_splt = X_train.iloc[1:splt,:] # to distinguish full X_train without holdout validation
print(len(X_train_splt))
print(len(X_val))

y_val = y_train.iloc[splt:]
y_train_splt = y_train.iloc[1:splt]
print(np.shape(y_train_splt))
print(np.shape(y_val))
# Out:
# 16503
# 4127
# (16503,)
# (4127,)

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics=['mean_squared_error', 'mae'])
# note using root_mean_squared_error here can cause issue copying model later without config set, using grid search.

# %%
# note we could have said validation_split,0.2. We can set shuffle here too... shuffle=True,
history = model.fit(X_train_splt, y_train_splt ,batch_size = 128, epochs = 30,verbose=1,
                   callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=5,
                                                     verbose=0, mode='min')],
                   validation_data=(X_val, y_val))
# Out:
# Epoch 1/30
# 129/129 [==============================] - 2s 5ms/step - loss: 9938.7773 - mean_squared_error: 9938.7773 - mae: 89.5205 - val_loss: 8491.0537 - val_mean_squared_error: 8491.0537 - val_mae: 83.2401
# Epoch 2/30
# 129/129 [==============================] - 0s 3ms/step - loss: 7259.2515 - mean_squared_error: 7259.2515 - mae: 76.4250 - val_loss: 5413.8320 - val_mean_squared_error: 5413.8320 - val_mae: 66.2083
# Epoch 3/30
# 129/129 [==============================] - 0s 3ms/step - loss: 4257.6968 - mean_squared_error: 4257.6968 - mae: 57.6636 - val_loss: 2464.8835 - val_mean_squared_error: 2464.8835 - val_mae: 42.8798
# Epoch 4/30
# 129/129 [==============================] - 0s 3ms/step - loss: 1985.5835 - mean_squared_error: 1985.5835 - mae: 37.6583 - val_loss: 1002.4307 - val_mean_squared_error: 1002.4307 - val_mae: 25.7922
# Epoch 5/30
# 129/129 [==============================] - 0s 3ms/step - loss: 875.7518 - mean_squared_error: 875.7518 - mae: 23.6733 - val_loss: 728.6006 - val_mean_squared_error: 728.6006 - val_mae: 21.3227
# Epoch 6/30
# 129/129 [==============================] - 0s 3ms/step - loss: 555.8949 - mean_squared_error: 555.8949 - mae: 18.1540 - val_loss: 626.8044 - val_mean_squared_error: 626.8044 - val_mae: 19.5477
# Epoch 7/30
# 129/129 [==============================] - 0s 3ms/step - loss: 493.2655 - mean_squared_error: 493.2655 - mae: 16.8094 - val_loss: 486.0074 - val_mean_squared_error: 486.0074 - val_mae: 16.9953
# Epoch 8/30
# 129/129 [==============================] - 0s 3ms/step - loss: 471.9967 - mean_squared_error: 471.9967 - mae: 16.3513 - val_loss: 473.2039 - val_mean_squared_error: 473.2039 - val_mae: 16.9864
# Epoch 9/30
# 129/129 [==============================] - 0s 3ms/step - loss: 469.4895 - mean_squared_error: 469.4895 - mae: 16.2981 - val_loss: 437.8600 - val_mean_squared_error: 437.8600 - val_mae: 16.0329
# Epoch 10/30
# 129/129 [==============================] - 0s 3ms/step - loss: 469.8926 - mean_squared_error: 469.8926 - mae: 16.2031 - val_loss: 433.3235 - val_mean_squared_error: 433.3235 - val_mae: 15.9885
# Epoch 11/30
# 129/129 [==============================] - 0s 3ms/step - loss: 465.9033 - mean_squared_error: 465.9033 - mae: 16.2157 - val_loss: 422.7924 - val_mean_squared_error: 422.7924 - val_mae: 15.1373
# Epoch 12/30
# 129/129 [==============================] - 0s 3ms/step - loss: 461.5428 - mean_squared_error: 461.5428 - mae: 16.1172 - val_loss: 426.4608 - val_mean_squared_error: 426.4608 - val_mae: 15.5546
# Epoch 13/30
# 129/129 [==============================] - 0s 3ms/step - loss: 454.2623 - mean_squared_error: 454.2623 - mae: 15.9284 - val_loss: 416.3767 - val_mean_squared_error: 416.3767 - val_mae: 14.9639
# Epoch 14/30
# 129/129 [==============================] - 0s 3ms/step - loss: 461.8472 - mean_squared_error: 461.8472 - mae: 15.9984 - val_loss: 418.2894 - val_mean_squared_error: 418.2894 - val_mae: 14.7322
# Epoch 15/30
# 129/129 [==============================] - 0s 3ms/step - loss: 455.3542 - mean_squared_error: 455.3542 - mae: 15.9782 - val_loss: 417.6342 - val_mean_squared_error: 417.6342 - val_mae: 15.2131
# Epoch 16/30
# 129/129 [==============================] - 0s 3ms/step - loss: 462.2983 - mean_squared_error: 462.2983 - mae: 16.0922 - val_loss: 416.5814 - val_mean_squared_error: 416.5814 - val_mae: 14.7251
# Epoch 17/30
# 129/129 [==============================] - 0s 3ms/step - loss: 456.1851 - mean_squared_error: 456.1851 - mae: 15.9924 - val_loss: 415.6248 - val_mean_squared_error: 415.6248 - val_mae: 14.9532
# Epoch 18/30
# 129/129 [==============================] - 0s 3ms/step - loss: 453.7036 - mean_squared_error: 453.7036 - mae: 15.9263 - val_loss: 416.8183 - val_mean_squared_error: 416.8183 - val_mae: 14.8542
# Epoch 19/30
# 129/129 [==============================] - 0s 3ms/step - loss: 454.2421 - mean_squared_error: 454.2421 - mae: 15.8914 - val_loss: 418.3466 - val_mean_squared_error: 418.3466 - val_mae: 15.1951
# Epoch 20/30
# 129/129 [==============================] - 0s 3ms/step - loss: 454.7426 - mean_squared_error: 454.7426 - mae: 16.0095 - val_loss: 414.3560 - val_mean_squared_error: 414.3560 - val_mae: 14.7308
# Epoch 21/30
# 129/129 [==============================] - 0s 3ms/step - loss: 455.1176 - mean_squared_error: 455.1176 - mae: 15.9107 - val_loss: 412.7344 - val_mean_squared_error: 412.7344 - val_mae: 14.8054
# Epoch 22/30
# 129/129 [==============================] - 0s 3ms/step - loss: 445.8207 - mean_squared_error: 445.8207 - mae: 15.7620 - val_loss: 418.8779 - val_mean_squared_error: 418.8779 - val_mae: 15.2718
# Epoch 23/30
# 129/129 [==============================] - 0s 3ms/step - loss: 443.4350 - mean_squared_error: 443.4350 - mae: 15.7025 - val_loss: 414.0578 - val_mean_squared_error: 414.0578 - val_mae: 15.0378
# Epoch 24/30
# 129/129 [==============================] - 0s 3ms/step - loss: 461.9704 - mean_squared_error: 461.9704 - mae: 16.0507 - val_loss: 412.0377 - val_mean_squared_error: 412.0377 - val_mae: 15.0974
# Epoch 25/30
# 129/129 [==============================] - 0s 3ms/step - loss: 456.5357 - mean_squared_error: 456.5357 - mae: 16.0197 - val_loss: 412.5621 - val_mean_squared_error: 412.5621 - val_mae: 14.6949
# Epoch 26/30
# 129/129 [==============================] - 0s 3ms/step - loss: 447.1906 - mean_squared_error: 447.1906 - mae: 15.7891 - val_loss: 421.4579 - val_mean_squared_error: 421.4579 - val_mae: 15.5939
# Epoch 27/30
# 129/129 [==============================] - 0s 3ms/step - loss: 442.6076 - mean_squared_error: 442.6076 - mae: 15.7137 - val_loss: 413.8747 - val_mean_squared_error: 413.8747 - val_mae: 14.9632
# Epoch 28/30
# 129/129 [==============================] - 0s 3ms/step - loss: 446.5658 - mean_squared_error: 446.5658 - mae: 15.7508 - val_loss: 415.1447 - val_mean_squared_error: 415.1447 - val_mae: 15.0684
# Epoch 29/30
# 129/129 [==============================] - 0s 3ms/step - loss: 447.2069 - mean_squared_error: 447.2069 - mae: 15.7647 - val_loss: 414.8408 - val_mean_squared_error: 414.8408 - val_mae: 14.7369

# %%
# summarize history for MAE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['mae'])
plt.plot(history.history['val_mae'])
plt.title('model MAE')
plt.ylabel('MAE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
fig_acc.savefig("model_mae.png")

# summarize history for RMSE
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('model MSE')
plt.ylabel('MSE')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
fig_acc.savefig("model_rmse.png")

# summarize history for Loss
fig_acc = plt.figure(figsize=(10, 10))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left') 
plt.show()
fig_acc.savefig("model_regression_loss.png")

# %%
model_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,model_pred)
# Out:
# 0.5696872001305417

# %%
from sklearn.metrics import mean_squared_error
RMSE = np.sqrt(mean_squared_error(y_test,model_pred))
print("RMSE: ", RMSE)
# Out:
# RMSE:  27.259752247323366

# %%
plt.scatter(y_test,model_pred)
plt.xlabel("Ground truth RUL")
plt.ylabel("Predicted RUL")
plt.show()

plt.hist(y_test, color = "lightgreen", ec="black")
plt.xlabel("Ground truth RUL, test set")
plt.show()

plt.hist(y_train, color = "lightblue", ec="black")
plt.xlabel("Ground truth RUL, training")
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               4096
#
#  batch_normalization (BatchN  (None, 256)              1024
#  ormalization)
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 128)               0
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  activation_2 (Activation)   (None, 128)               0
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 55,681
# Trainable params: 54,657
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
# define the grid search parameters
batch_size = [16, 32, 64]
epochs = [10, 15, 20]
learn_rate = [0.0001, 0.001, 0.01]
momentum = [0.1, 0.2, 0.4, 0.6, 0.8, 0.9]
# param_grid = dict(optimizer__learning_rate=learn_rate, optimizer__momentum=momentum, batch_size=batch_size, epochs=epochs)
# param_grid = dict(optimizer__learning_rate=learn_rate, optimizer__momentum=momentum)
param_grid = dict(batch_size=batch_size, epochs=epochs)

# %%
model2 = KerasRegressor(build_fn=model, epochs=100, batch_size=128, verbose=0)
grid = GridSearchCV(estimator=model2, param_grid=param_grid, n_jobs=-1, cv=3, scoring='neg_mean_squared_error')

grid_result = grid.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmprmy3s20b\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpzu3r76w0\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpq98evl9y\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmph3g1z2o_\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmp300ub863\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpgt82_rhl\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpr4q1ypj9\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpkv9hsvxy\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpe0uz_0lo\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpbxsxqxjo\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmps1sp_nvd\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpkua6dm71\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpwbj_74h0\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpbwos7y13\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpo3kpfgoc\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmp_wj838zy\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpcwtv6_it\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmphygijwhi\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpbaz4yp7i\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmph630q8vh\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpge_i8exx\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpy0z3srj6\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmplf6xh_xf\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpjog94diz\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmp63a4a2lb\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpfcbl0v62\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpht0dyq9k\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmper_5oq6q\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmp40l67_rx\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpu3wej0bn\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpwmbzx7pw\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmp5eqnoihl\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpyyqpzw4e\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmptgni4eu7\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpnu9_gl0z\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmp6c5rw_d_\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpsytuwbyu\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmptn927s79\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpciupv1j8\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpjtceumau\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpseblv1gp\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpv1wqs9kw\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmp04l670qy\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpydsoi72s\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpe66rhax9\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpkrph5781\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmp5dj7fx30\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpxttacly4\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpcr9hha6r\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmphf9p99fc\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmphd05ht07\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpom10fopd\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmptes7vc5p\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpymav73tk\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmpdk18f3qa\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmplxtv49k7\assets
# INFO:tensorflow:Assets written to: C:\Users\stuar\AppData\Local\Temp\tmp53t0r4ur\assets
# Best: -392.920959 using {'batch_size': 64, 'epochs': 20}
# -410.240875 (6.132503) with: {'batch_size': 16, 'epochs': 10}
# -405.580321 (6.848219) with: {'batch_size': 16, 'epochs': 15}
# -414.051390 (7.244069) with: {'batch_size': 16, 'epochs': 20}
# -400.693036 (7.009453) with: {'batch_size': 32, 'epochs': 10}
# -397.167787 (2.720543) with: {'batch_size': 32, 'epochs': 15}
# -399.600524 (5.914870) with: {'batch_size': 32, 'epochs': 20}
# -394.262758 (6.264538) with: {'batch_size': 64, 'epochs': 10}
# -395.022479 (6.765362) with: {'batch_size': 64, 'epochs': 15}
# -392.920959 (5.856525) with: {'batch_size': 64, 'epochs': 20}

# %%
plt.plot(means)
plt.title("Mean square error")
plt.show()

plt.plot(np.sqrt(np.abs(means)))
plt.title("Root Mean square error")
plt.show()

# %%
model_gs = grid.best_estimator_
model_pred = model_gs.predict(X_test)

# %%
r2_score(y_test,model_pred)
# Out:
# 0.5621478834567568

# %%
RMSE = np.sqrt(mean_squared_error(y_test,model_pred))
print("RMSE: ", RMSE)
# Out:
# RMSE:  27.497518239910008

# %% [markdown]
# This next section may be easier to view in a new window, or see image noted in powerpoint.
# It shows why we removed certain signals

# %%
pd.plotting.scatter_matrix(train,figsize=[20,20])
plt.show()
